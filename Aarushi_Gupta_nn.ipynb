# %% [markdown]
# ## Melanoma Detection
# ### Submitted By:- Aarushi Gupta
# ##### Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Relevent Libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras import regularizers

# %% [markdown]
# ### Mounting Google Drive

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Defining the path for test and train data

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
root_path = '/content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration'
data_dir_train = pathlib.Path(root_path + '/Train')
data_dir_test = pathlib.Path(root_path + '/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# ### Load using keras.preprocessing

# %% [markdown]
# ### Creating the dataset

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset

train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, validation_split=0.2, subset="training", seed=123,\
  image_size=(img_height, img_width), batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, validation_split=0.2, subset="validation", seed=123,\
  image_size=(img_height, img_width), batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
## Write your test dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
test_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_test, image_size=(img_height, img_width), batch_size=batch_size)
# Out:
# Found 118 files belonging to 9 classes.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualizing the Data

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(2):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# The image_batch is a tensor of the shape (32, 180, 180, 3). This is a batch of 32 images of shape 180x180x3 (the last dimension refers to color channels RGB). The label_batch is a tensor of the shape (32,), these are corresponding labels to the 32 images.
#
# Dataset.cache() keeps the images in memory after they're loaded off disk during the first epoch.
#
# Dataset.prefetch() overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Creating the model

# %% [markdown]
# ### Model 1
# Create a CNN model, which can accurately detect 9 classes present in the dataset. Use layers.experimental.preprocessing.Rescaling to normalize pixel values between (0,1). The RGB channel values are in the [0, 255] range. This is not ideal for a neural network. Here, it is good to standardize values to be in the [0, 1]

# %%
input_shape = (180,180,3)
num_classes = 9

model = Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, offset=0.0, input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), input_shape=input_shape, padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(32, kernel_size=(3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
#model.add(Dense(512, kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
### Compiling the model
### choosing an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
### Training the model
epochs = 20
batch_size = 32
history = model.fit(train_ds, validation_data=val_ds, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 292s 3s/step - loss: 9.5665 - accuracy: 0.2913 - val_loss: 4.1557 - val_accuracy: 0.0984
# Epoch 2/20
# 56/56 [==============================] - 6s 110ms/step - loss: 2.7747 - accuracy: 0.3767 - val_loss: 22.1189 - val_accuracy: 0.0447
# Epoch 3/20
# 56/56 [==============================] - 6s 110ms/step - loss: 1.6098 - accuracy: 0.4883 - val_loss: 13.9386 - val_accuracy: 0.0582
# Epoch 4/20
# 56/56 [==============================] - 6s 111ms/step - loss: 1.4756 - accuracy: 0.4916 - val_loss: 6.9785 - val_accuracy: 0.1499
# Epoch 5/20
# 56/56 [==============================] - 6s 112ms/step - loss: 1.2781 - accuracy: 0.5608 - val_loss: 15.6338 - val_accuracy: 0.1812
# Epoch 6/20
# 56/56 [==============================] - 6s 113ms/step - loss: 1.1443 - accuracy: 0.5865 - val_loss: 9.8426 - val_accuracy: 0.2394
# Epoch 7/20
# 56/56 [==============================] - 6s 113ms/step - loss: 0.9464 - accuracy: 0.6568 - val_loss: 3.3561 - val_accuracy: 0.2819
# Epoch 8/20
# 56/56 [==============================] - 6s 112ms/step - loss: 0.8006 - accuracy: 0.6953 - val_loss: 3.1297 - val_accuracy: 0.3378
# Epoch 9/20
# 56/56 [==============================] - 6s 111ms/step - loss: 0.7195 - accuracy: 0.7333 - val_loss: 2.2054 - val_accuracy: 0.4072
# Epoch 10/20
# 56/56 [==============================] - 6s 112ms/step - loss: 0.5604 - accuracy: 0.7963 - val_loss: 2.0521 - val_accuracy: 0.4676
# Epoch 11/20
# 56/56 [==============================] - 6s 111ms/step - loss: 0.4879 - accuracy: 0.8036 - val_loss: 2.3995 - val_accuracy: 0.4989
# Epoch 12/20
# 56/56 [==============================] - 6s 111ms/step - loss: 0.4185 - accuracy: 0.8309 - val_loss: 2.1013 - val_accuracy: 0.5034
# Epoch 13/20
# 56/56 [==============================] - 6s 111ms/step - loss: 0.3747 - accuracy: 0.8549 - val_loss: 2.3731 - val_accuracy: 0.5078
# Epoch 14/20
# 56/56 [==============================] - 6s 112ms/step - loss: 0.3545 - accuracy: 0.8700 - val_loss: 2.6919 - val_accuracy: 0.5302
# Epoch 15/20
# 56/56 [==============================] - 6s 112ms/step - loss: 0.3303 - accuracy: 0.8722 - val_loss: 2.9261 - val_accuracy: 0.4787
# Epoch 16/20
# 56/56 [==============================] - 6s 112ms/step - loss: 0.3086 - accuracy: 0.8811 - val_loss: 2.4289 - val_accuracy: 0.4676
# Epoch 17/20
# 56/56 [==============================] - 6s 113ms/step - loss: 0.2890 - accuracy: 0.8945 - val_loss: 2.7512 - val_accuracy: 0.4653
# Epoch 18/20
# 56/56 [==============================] - 6s 113ms/step - loss: 0.2430 - accuracy: 0.9012 - val_loss: 3.9050 - val_accuracy: 0.4855
# Epoch 19/20
# 56/56 [==============================] - 6s 112ms/step - loss: 0.2465 - accuracy: 0.9224 - val_loss: 2.8283 - val_accuracy: 0.4810
# Epoch 20/20
# 56/56 [==============================] - 6s 112ms/step - loss: 0.1697 - accuracy: 0.9258 - val_loss: 3.6840 - val_accuracy: 0.4407

# %%
### View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      896
#
#  activation (Activation)     (None, 180, 180, 32)      0
#
#  batch_normalization (BatchN  (None, 180, 180, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 178, 178, 32)      9248
#
#  activation_1 (Activation)   (None, 178, 178, 32)      0
#
#  batch_normalization_1 (Batc  (None, 178, 178, 32)     128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 89, 89, 64)        18496
#
#  activation_2 (Activation)   (None, 89, 89, 64)        0
#
#  batch_normalization_2 (Batc  (None, 89, 89, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 87, 87, 64)        36928
#
#  activation_3 (Activation)   (None, 87, 87, 64)        0
#
#  batch_normalization_3 (Batc  (None, 87, 87, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 43, 43, 128)       73856
#
#  activation_4 (Activation)   (None, 43, 43, 128)       0
#
#  batch_normalization_4 (Batc  (None, 43, 43, 128)      512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 41, 41, 128)       147584
#
#  activation_5 (Activation)   (None, 41, 41, 128)       0
#
#  batch_normalization_5 (Batc  (None, 41, 41, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 51200)             0
#
#  dense (Dense)               (None, 256)               13107456
#
#  activation_6 (Activation)   (None, 256)               0
#
#  dense_1 (Dense)             (None, 9)                 2313
#
#  activation_7 (Activation)   (None, 9)                 0
#
# =================================================================
# Total params: 13,398,569
# Trainable params: 13,397,673
# Non-trainable params: 896
# _________________________________________________________________

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# 1. The accuracy of the model for the Training data set is at 92%. But the Validation accuracy is not in par with the training accuracy.
# It is only at 44%.
# 2. The validation loss as observed is very high.This could also be indicative of some Overfitting in the model.
# 3. We could add some Dropout layers and remove the BatchNormalization layers to avoid overfitting to some extent

# %% [markdown]
# ### Model 2
# #### Removing Batch Normalization and Adding Dropouts.

# %%
input_shape = (180,180,3)
num_classes = 9

model = Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, offset=0.0, input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), input_shape=input_shape, padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(32, kernel_size=(3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.50))

model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.50))

model.add(Conv2D(128, kernel_size=(3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.50))

model.add(Flatten())
#model.add(Dense(512, kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.50))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
### compiling the model
### choosing an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
### training the model
epochs = 20
batch_size = 32
history = model.fit(train_ds, validation_data=val_ds, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 7s 107ms/step - loss: 2.1912 - accuracy: 0.1802 - val_loss: 2.0548 - val_accuracy: 0.2058
# Epoch 2/20
# 56/56 [==============================] - 5s 96ms/step - loss: 2.0418 - accuracy: 0.1808 - val_loss: 2.0242 - val_accuracy: 0.2058
# Epoch 3/20
# 56/56 [==============================] - 5s 97ms/step - loss: 2.0325 - accuracy: 0.1842 - val_loss: 2.0277 - val_accuracy: 0.2058
# Epoch 4/20
# 56/56 [==============================] - 5s 95ms/step - loss: 2.0208 - accuracy: 0.1953 - val_loss: 2.0194 - val_accuracy: 0.1924
# Epoch 5/20
# 56/56 [==============================] - 5s 96ms/step - loss: 2.0242 - accuracy: 0.1987 - val_loss: 2.0212 - val_accuracy: 0.1924
# Epoch 6/20
# 56/56 [==============================] - 5s 95ms/step - loss: 2.0262 - accuracy: 0.1942 - val_loss: 2.0367 - val_accuracy: 0.1924
# Epoch 7/20
# 56/56 [==============================] - 5s 95ms/step - loss: 2.0340 - accuracy: 0.2098 - val_loss: 2.0220 - val_accuracy: 0.2058
# Epoch 8/20
# 56/56 [==============================] - 5s 95ms/step - loss: 2.0197 - accuracy: 0.1981 - val_loss: 2.0257 - val_accuracy: 0.2058
# Epoch 9/20
# 56/56 [==============================] - 5s 95ms/step - loss: 2.0258 - accuracy: 0.1908 - val_loss: 2.0222 - val_accuracy: 0.2058
# Epoch 10/20
# 56/56 [==============================] - 5s 96ms/step - loss: 2.0071 - accuracy: 0.2109 - val_loss: 1.9647 - val_accuracy: 0.3221
# Epoch 11/20
# 56/56 [==============================] - 6s 98ms/step - loss: 1.9273 - accuracy: 0.2662 - val_loss: 1.8443 - val_accuracy: 0.3468
# Epoch 12/20
# 56/56 [==============================] - 6s 100ms/step - loss: 1.8555 - accuracy: 0.3002 - val_loss: 1.7569 - val_accuracy: 0.3512
# Epoch 13/20
# 56/56 [==============================] - 5s 95ms/step - loss: 1.7538 - accuracy: 0.3527 - val_loss: 1.8087 - val_accuracy: 0.3244
# Epoch 14/20
# 56/56 [==============================] - 5s 97ms/step - loss: 1.6956 - accuracy: 0.3644 - val_loss: 1.5843 - val_accuracy: 0.4362
# Epoch 15/20
# 56/56 [==============================] - 5s 98ms/step - loss: 1.6440 - accuracy: 0.4018 - val_loss: 1.5751 - val_accuracy: 0.4206
# Epoch 16/20
# 56/56 [==============================] - 5s 98ms/step - loss: 1.6376 - accuracy: 0.4051 - val_loss: 1.5785 - val_accuracy: 0.4407
# Epoch 17/20
# 56/56 [==============================] - 5s 95ms/step - loss: 1.6122 - accuracy: 0.4280 - val_loss: 1.7026 - val_accuracy: 0.3736
# Epoch 18/20
# 56/56 [==============================] - 5s 95ms/step - loss: 1.6233 - accuracy: 0.4040 - val_loss: 1.5748 - val_accuracy: 0.4586
# Epoch 19/20
# 56/56 [==============================] - 5s 95ms/step - loss: 1.5842 - accuracy: 0.4241 - val_loss: 1.5482 - val_accuracy: 0.4452
# Epoch 20/20
# 56/56 [==============================] - 5s 95ms/step - loss: 1.5532 - accuracy: 0.4375 - val_loss: 1.5512 - val_accuracy: 0.4452

# %%
### visualizing the model results.
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# 1. The model is performing slightly better than the previous model since there is comparatively less overfitting.
# 2. Training accuracy and validation accuracy both comes out to be near 44%

# %% [markdown]
# ### Data Augmentation

# %% [markdown]
# ### Model 3
# #### Creating a model using data augmetation
# 1. layers.experimental.preprocessing.RandomFlip() - A preprocessing layer which randomly flips images during training.
# 2. layers.experimental.preprocessing.RandomRotation() - A preprocessing layer which randomly rotates images during training.

# %%
data_augmentation=tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandomRotation(0.3)
])

# %%
#### visualizing how your augmentation strategy works for one instance of training image.
image, label = next(iter(train_ds))
image=np.array(image,np.int32)  
plt.figure(figsize=(10, 10))
for i in range(9):
  augmented_image = data_augmentation(image)
  ax = plt.subplot(3, 3, i + 1)
  augmented_image1=np.array(augmented_image[0],np.int32)  
  plt.imshow((augmented_image1))
  plt.axis("off")

# %%
input_shape = (180,180,3)
num_classes = 9

model_aug = Sequential()
model_aug.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, offset=0.0))
model_aug.add(tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"))
model_aug.add(tf.keras.layers.experimental.preprocessing.RandomRotation(0.2))
model_aug.add(Conv2D(32, kernel_size=(3, 3), input_shape=input_shape, padding='same'))
model_aug.add(Activation('relu'))
model_aug.add(Conv2D(32, kernel_size=(3, 3)))
model_aug.add(Activation('relu'))
model_aug.add(MaxPooling2D(pool_size=(2, 2)))
model_aug.add(Dropout(0.50))

model_aug.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model_aug.add(Activation('relu'))
model_aug.add(Conv2D(64, (3, 3)))
model_aug.add(Activation('relu'))
model_aug.add(MaxPooling2D(pool_size=(2, 2)))
model_aug.add(Dropout(0.50))

model_aug.add(Conv2D(128, kernel_size=(3, 3), padding='same'))
model_aug.add(Activation('relu'))
model_aug.add(Conv2D(128, (3, 3)))
model_aug.add(Activation('relu'))
model_aug.add(MaxPooling2D(pool_size=(2, 2)))
model_aug.add(Dropout(0.50))

model_aug.add(Flatten())
model_aug.add(Dense(512))
model_aug.add(Activation('relu'))
model_aug.add(Dropout(0.50))
model_aug.add(Dense(num_classes))
model_aug.add(Activation('softmax'))

# %%
### compiling the augmented model
### choosing an appropirate optimiser and loss function
model_aug.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
### training the model
epochs = 20
batch_size = 32
history = model_aug.fit(train_ds, validation_data=val_ds, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 7s 100ms/step - loss: 2.1494 - accuracy: 0.1802 - val_loss: 2.0237 - val_accuracy: 0.1924
# Epoch 2/20
# 56/56 [==============================] - 5s 98ms/step - loss: 2.0305 - accuracy: 0.1858 - val_loss: 2.0275 - val_accuracy: 0.1924
# Epoch 3/20
# 56/56 [==============================] - 5s 98ms/step - loss: 2.0327 - accuracy: 0.2132 - val_loss: 2.0313 - val_accuracy: 0.2058
# Epoch 4/20
# 56/56 [==============================] - 6s 100ms/step - loss: 2.0301 - accuracy: 0.1836 - val_loss: 2.0212 - val_accuracy: 0.1924
# Epoch 5/20
# 56/56 [==============================] - 6s 100ms/step - loss: 1.9952 - accuracy: 0.1992 - val_loss: 1.9423 - val_accuracy: 0.3020
# Epoch 6/20
# 56/56 [==============================] - 6s 99ms/step - loss: 1.8485 - accuracy: 0.3153 - val_loss: 1.6914 - val_accuracy: 0.3803
# Epoch 7/20
# 56/56 [==============================] - 6s 99ms/step - loss: 1.8130 - accuracy: 0.3343 - val_loss: 1.7473 - val_accuracy: 0.3579
# Epoch 8/20
# 56/56 [==============================] - 6s 98ms/step - loss: 1.7370 - accuracy: 0.3560 - val_loss: 1.6590 - val_accuracy: 0.3915
# Epoch 9/20
# 56/56 [==============================] - 5s 97ms/step - loss: 1.7250 - accuracy: 0.3588 - val_loss: 1.6920 - val_accuracy: 0.3870
# Epoch 10/20
# 56/56 [==============================] - 5s 97ms/step - loss: 1.7067 - accuracy: 0.3778 - val_loss: 1.6251 - val_accuracy: 0.4206
# Epoch 11/20
# 56/56 [==============================] - 5s 97ms/step - loss: 1.6391 - accuracy: 0.3973 - val_loss: 1.5966 - val_accuracy: 0.4385
# Epoch 12/20
# 56/56 [==============================] - 5s 97ms/step - loss: 1.6272 - accuracy: 0.4146 - val_loss: 1.5952 - val_accuracy: 0.4474
# Epoch 13/20
# 56/56 [==============================] - 5s 97ms/step - loss: 1.6259 - accuracy: 0.4085 - val_loss: 1.5940 - val_accuracy: 0.4541
# Epoch 14/20
# 56/56 [==============================] - 5s 96ms/step - loss: 1.6206 - accuracy: 0.4068 - val_loss: 1.6313 - val_accuracy: 0.4116
# Epoch 15/20
# 56/56 [==============================] - 5s 98ms/step - loss: 1.5962 - accuracy: 0.4185 - val_loss: 1.5850 - val_accuracy: 0.4519
# Epoch 16/20
# 56/56 [==============================] - 6s 105ms/step - loss: 1.5945 - accuracy: 0.4129 - val_loss: 1.5675 - val_accuracy: 0.4362
# Epoch 17/20
# 56/56 [==============================] - 5s 97ms/step - loss: 1.6006 - accuracy: 0.4169 - val_loss: 1.6244 - val_accuracy: 0.4206
# Epoch 18/20
# 56/56 [==============================] - 6s 100ms/step - loss: 1.5618 - accuracy: 0.4252 - val_loss: 1.5568 - val_accuracy: 0.4407
# Epoch 19/20
# 56/56 [==============================] - 5s 97ms/step - loss: 1.5343 - accuracy: 0.4632 - val_loss: 1.5548 - val_accuracy: 0.4899
# Epoch 20/20
# 56/56 [==============================] - 5s 97ms/step - loss: 1.4883 - accuracy: 0.4509 - val_loss: 1.5168 - val_accuracy: 0.5101

# %%
### summary of the above model
model_aug.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_4 (Rescaling)     (None, 180, 180, 3)       0
#
#  random_flip_3 (RandomFlip)  (None, 180, 180, 3)       0
#
#  random_rotation_3 (RandomRo  (None, 180, 180, 3)      0
#  tation)
#
#  conv2d_24 (Conv2D)          (None, 180, 180, 32)      896
#
#  activation_32 (Activation)  (None, 180, 180, 32)      0
#
#  conv2d_25 (Conv2D)          (None, 178, 178, 32)      9248
#
#  activation_33 (Activation)  (None, 178, 178, 32)      0
#
#  max_pooling2d_12 (MaxPoolin  (None, 89, 89, 32)       0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 89, 89, 32)        0
#
#  conv2d_26 (Conv2D)          (None, 89, 89, 64)        18496
#
#  activation_34 (Activation)  (None, 89, 89, 64)        0
#
#  conv2d_27 (Conv2D)          (None, 87, 87, 64)        36928
#
#  activation_35 (Activation)  (None, 87, 87, 64)        0
#
#  max_pooling2d_13 (MaxPoolin  (None, 43, 43, 64)       0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 43, 43, 64)        0
#
#  conv2d_28 (Conv2D)          (None, 43, 43, 128)       73856
#
#  activation_36 (Activation)  (None, 43, 43, 128)       0
#
#  conv2d_29 (Conv2D)          (None, 41, 41, 128)       147584
#
#  activation_37 (Activation)  (None, 41, 41, 128)       0
#
#  max_pooling2d_14 (MaxPoolin  (None, 20, 20, 128)      0
#  g2D)
#
#  dropout_14 (Dropout)        (None, 20, 20, 128)       0
#
#  flatten_4 (Flatten)         (None, 51200)             0
#
#  dense_8 (Dense)             (None, 256)               13107456
#
#  activation_38 (Activation)  (None, 256)               0
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  dense_9 (Dense)             (None, 9)                 2313
#
#  activation_39 (Activation)  (None, 9)                 0
#
# =================================================================
# Total params: 13,396,777
# Trainable params: 13,396,777
# Non-trainable params: 0
# _________________________________________________________________

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# 1. Including Data Augmentation has improved the model accuracy to 50% and also handled overfitting to some extent.
# 2. Data Augmentation has improved the model performance.

# %% [markdown]
# ### Model Building & training on the rectified class imbalance data

# %% [markdown]
# ### Model 4
#
# Context: Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
### defining the path for training and test images
train_path = "/content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
test_path = "/content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test/"

# %%
### distibution of classes for each category of data
### It can be seen that data has imbalances in the class distribution
for i in class_names:
    directory =train_path + i + '/'
    class_directory = pathlib.Path(directory)
    length=len(list(class_directory.glob('*.jpg')))
    print(f'{i} has {length} samples.')
# Out:
# actinic keratosis has 114 samples.
# basal cell carcinoma has 376 samples.
# dermatofibroma has 95 samples.
# melanoma has 438 samples.
# nevus has 357 samples.
# pigmented benign keratosis has 462 samples.
# seborrheic keratosis has 77 samples.
# squamous cell carcinoma has 181 samples.
# vascular lesion has 139 samples.

# %% [markdown]
# - seborrheic keratosis has least number of samples - 77
# - pigmented benign keratosis has maximum number of samples - 462

# %% [markdown]
# You can use a python package known as Augmentor (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.0)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %% [markdown]
# To use Augmentor, the following general procedure is followed:
#
# 1. Instantiate a Pipeline object pointing to a directory containing your initial image data set.
# 2. Define a number of operations to perform on this data set using your Pipeline object.
# 3. Execute these operations by calling the Pipeline’s sample() method.

# %%
path_to_training_dataset=train_path
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FDD030ED1D0>: 100%|██████████| 500/500 [00:18<00:00, 27.33 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FDD000D8110>: 100%|██████████| 500/500 [00:19<00:00, 25.99 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7FDD0015C690>: 100%|██████████| 500/500 [00:19<00:00, 26.13 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FDD1607BED0>: 100%|██████████| 500/500 [01:36<00:00,  5.18 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=919x802 at 0x7FDD943CD810>: 100%|██████████| 500/500 [01:30<00:00,  5.54 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FDD1628CB10>: 100%|██████████| 500/500 [00:18<00:00, 27.41 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FDD96693C90>: 100%|██████████| 500/500 [00:44<00:00, 11.34 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FDD978A8850>: 100%|██████████| 500/500 [00:18<00:00, 27.18 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7FDD03F6DC90>: 100%|██████████| 500/500 [00:17<00:00, 28.14 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %% [markdown]
# ### The distribution of augmented data after adding new images to the original training data.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %%
from glob import glob
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
### Distribution of classes after augmentation
for i in class_names:
    directory =train_path+i+'/'
    directory_out =train_path+i+'/output/'
    class_directory = pathlib.Path(directory)
    class_directory_out = pathlib.Path(directory_out)
    length=len(list(class_directory.glob('*.jpg')))
    length_out=len(list(class_directory_out.glob('*.jpg')))
    length_tot=length+length_out
    print(f'{i} has {length_tot} samples.')
# Out:
# actinic keratosis has 614 samples.
# basal cell carcinoma has 876 samples.
# dermatofibroma has 595 samples.
# melanoma has 938 samples.
# nevus has 857 samples.
# pigmented benign keratosis has 962 samples.
# seborrheic keratosis has 577 samples.
# squamous cell carcinoma has 681 samples.
# vascular lesion has 639 samples.

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# ### Training the model on the data created using Augmentor

# %% [markdown]
# ### Create a training dataset

# %%
data_dir_train=train_path
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123, label_mode='categorical',
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# ### Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123, label_mode='categorical',
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# ### Creating the model

# %%
input_shape = (180,180,3)
num_classes = 9

model = Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, offset=0.0))
model.add(Conv2D(32, kernel_size=(3, 3), input_shape=input_shape, padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(32, kernel_size=(3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.10))

model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.10))

model.add(Conv2D(128, kernel_size=(3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.10))

model.add(Flatten())
#model.add(Dense(512, kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %% [markdown]
# ### Compiling the model

# %%
### choosing an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
epochs = 30
batch_size = 32
history = model.fit(train_ds, validation_data=val_ds, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 139s 205ms/step - loss: 1.9126 - accuracy: 0.2687 - val_loss: 1.7799 - val_accuracy: 0.3341
# Epoch 2/30
# 169/169 [==============================] - 35s 201ms/step - loss: 1.6270 - accuracy: 0.3774 - val_loss: 1.4914 - val_accuracy: 0.4491
# Epoch 3/30
# 169/169 [==============================] - 34s 194ms/step - loss: 1.4536 - accuracy: 0.4319 - val_loss: 1.3084 - val_accuracy: 0.5041
# Epoch 4/30
# 169/169 [==============================] - 35s 202ms/step - loss: 1.3151 - accuracy: 0.5050 - val_loss: 1.1922 - val_accuracy: 0.5583
# Epoch 5/30
# 169/169 [==============================] - 34s 194ms/step - loss: 1.2016 - accuracy: 0.5480 - val_loss: 1.0846 - val_accuracy: 0.5984
# Epoch 6/30
# 169/169 [==============================] - 34s 195ms/step - loss: 1.0249 - accuracy: 0.6144 - val_loss: 1.0332 - val_accuracy: 0.6392
# Epoch 7/30
# 169/169 [==============================] - 35s 203ms/step - loss: 0.8693 - accuracy: 0.6771 - val_loss: 1.0112 - val_accuracy: 0.6518
# Epoch 8/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.7474 - accuracy: 0.7341 - val_loss: 0.9330 - val_accuracy: 0.7053
# Epoch 9/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.6413 - accuracy: 0.7693 - val_loss: 0.9440 - val_accuracy: 0.7283
# Epoch 10/30
# 169/169 [==============================] - 35s 202ms/step - loss: 0.5273 - accuracy: 0.8093 - val_loss: 0.8667 - val_accuracy: 0.7617
# Epoch 11/30
# 169/169 [==============================] - 34s 197ms/step - loss: 0.4432 - accuracy: 0.8412 - val_loss: 1.0387 - val_accuracy: 0.7194
# Epoch 12/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.4502 - accuracy: 0.8463 - val_loss: 0.8257 - val_accuracy: 0.7847
# Epoch 13/30
# 169/169 [==============================] - 36s 205ms/step - loss: 0.3215 - accuracy: 0.8846 - val_loss: 1.0538 - val_accuracy: 0.7691
# Epoch 14/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.2837 - accuracy: 0.9015 - val_loss: 0.8627 - val_accuracy: 0.8151
# Epoch 15/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.2601 - accuracy: 0.9089 - val_loss: 0.8209 - val_accuracy: 0.8040
# Epoch 16/30
# 169/169 [==============================] - 35s 202ms/step - loss: 0.2515 - accuracy: 0.9119 - val_loss: 1.2266 - val_accuracy: 0.6993
# Epoch 17/30
# 169/169 [==============================] - 34s 194ms/step - loss: 0.2224 - accuracy: 0.9162 - val_loss: 0.8488 - val_accuracy: 0.8062
# Epoch 18/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.2199 - accuracy: 0.9197 - val_loss: 0.9450 - val_accuracy: 0.7862
# Epoch 19/30
# 169/169 [==============================] - 35s 202ms/step - loss: 0.1738 - accuracy: 0.9340 - val_loss: 0.8621 - val_accuracy: 0.8010
# Epoch 20/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.1770 - accuracy: 0.9358 - val_loss: 1.0044 - val_accuracy: 0.7795
# Epoch 21/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.2115 - accuracy: 0.9258 - val_loss: 0.8409 - val_accuracy: 0.8062
# Epoch 22/30
# 169/169 [==============================] - 35s 202ms/step - loss: 0.1887 - accuracy: 0.9362 - val_loss: 0.9360 - val_accuracy: 0.7736
# Epoch 23/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.1662 - accuracy: 0.9338 - val_loss: 0.8488 - val_accuracy: 0.8174
# Epoch 24/30
# 169/169 [==============================] - 34s 198ms/step - loss: 0.1674 - accuracy: 0.9425 - val_loss: 0.9772 - val_accuracy: 0.7884
# Epoch 25/30
# 169/169 [==============================] - 34s 194ms/step - loss: 0.1418 - accuracy: 0.9458 - val_loss: 0.8533 - val_accuracy: 0.8211
# Epoch 26/30
# 169/169 [==============================] - 34s 195ms/step - loss: 0.1942 - accuracy: 0.9279 - val_loss: 1.0049 - val_accuracy: 0.7676
# Epoch 27/30
# 169/169 [==============================] - 35s 203ms/step - loss: 0.1514 - accuracy: 0.9438 - val_loss: 0.8400 - val_accuracy: 0.8107
# Epoch 28/30
# 169/169 [==============================] - 34s 194ms/step - loss: 0.1239 - accuracy: 0.9525 - val_loss: 0.8468 - val_accuracy: 0.8151
# Epoch 29/30
# 169/169 [==============================] - 34s 194ms/step - loss: 0.1128 - accuracy: 0.9527 - val_loss: 0.8000 - val_accuracy: 0.8411
# Epoch 30/30
# 169/169 [==============================] - 35s 202ms/step - loss: 0.1336 - accuracy: 0.9509 - val_loss: 0.7596 - val_accuracy: 0.8203

# %% [markdown]
# ### Visualizing the model

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Analysis of the result
# - Accuracy on training data has increased to around 82% by using Augmentor library of Python
# - Model is still overfitting to some extent
# - The problem of overfitting can be solved by adding more layer,neurons or dropout layers.
# - The above model can be further improved by tuning the hyperparameters.
